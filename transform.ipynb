# %%
import pandas as pd

# %%
df = pd.read_csv('datatset_consumer_complaints.csv')

traducao_produtos = {
    "Mortgage": "Empréstimo Imobiliário",
    "Debt collection": "Cobrança de Dívidas",
    "Bank account or service": "Conta Bancária ou Serviço Bancário",
    "Credit card": "Cartão de Crédito",
    "Credit reporting": "Relatório de Crédito",
    "Consumer Loan": "Empréstimo Pessoal",
    "Student loan": "Empréstimo Estudantil",
    "Payday loan": "Empréstimo Consignado",
    "Money transfers": "Transferências de Dinheiro",
    "Prepaid card": "Cartão Pré-Pago",
    "Other financial service": "Outro Serviço Financeiro",
    "Virtual currency": "Moeda Virtual"
}

df["Product"] = df["Product"].map(traducao_produtos)

# %%
issue_translation_dict = {
    "Loan servicing, payments, escrow account": "Serviço do empréstimo, pagamentos, conta garantia (escrow)",
    "Account opening, closing, or management": "Abertura, fechamento ou gerenciamento de conta",
    "Loan modification,collection,foreclosure": "Modificação de empréstimo, cobrança, execução hipotecária",
    "Communication tactics": "Táticas de comunicação",
    "Deposits and withdrawals": "Depósitos e saques",
    "Credit reporting company's investigation": "Investigação da empresa de relatório de crédito",
    "Application, originator, mortgage broker": "Aplicação, originador, corretor hipotecário",
    "Billing disputes": "Disputas de cobrança",
    "False statements or representation": "Declarações ou representações falsas",
    "Managing the loan or lease": "Gerenciamento do empréstimo ou leasing",
    "Unable to get credit report/credit score": "Incapaz de obter relatório de crédito/score",
    "Dealing with my lender or servicer": "Lidando com meu credor ou agente",
    "Problems caused by my funds being low": "Problemas causados por fundos insuficientes",
    "Improper contact or sharing of info": "Contato inadequado ou compartilhamento de informações",
    "Settlement process and costs": "Processo de liquidação e custos",
    "Taking/threatening an illegal action": "Tomada ou ameaça de ação ilegal",
    "Problems when you are unable to pay": "Problemas ao não conseguir pagar",
    "Identity theft / Fraud / Embezzlement": "Roubo de identidade / Fraude / Desfalque",
    "Making/receiving payments, sending money": "Fazendo/recebendo pagamentos, enviando dinheiro",
    "Can't repay my loan": "Não consigo pagar meu empréstimo",
    "Improper use of my credit report": "Uso indevido do meu relatório de crédito",
    "Closing/Cancelling account": "Fechamento/cancelamento de conta",
    "Using a debit or ATM card": "Uso de cartão de débito ou caixa eletrônico",
    "Credit decision / Underwriting": "Decisão de crédito / Subscrição",
    "Credit monitoring or identity protection": "Monitoramento de crédito ou proteção de identidade",
    "Taking out the loan or lease": "Contratação de empréstimo ou leasing",
    "APR or interest rate": "Taxa de juros ou APR",
    "Delinquent account": "Conta inadimplente",
    "Advertising and marketing": "Publicidade e marketing",
    "Fraud or scam": "Fraude ou golpe",
    "Customer service / Customer relations": "Atendimento ao cliente / Relações com o cliente",
    "Charged fees or interest I didn't expect": "Cobranças ou juros inesperados",
    "Rewards": "Recompensas",
    "Credit determination": "Determinação de crédito",
    "Billing statement": "Fatura",
    "Repaying your loan": "Pagamento do empréstimo",
    "Credit card protection / Debt protection": "Proteção de cartão de crédito / Dívida",
    "Late fee": "Multa por atraso",
    "Transaction issue": "Problema de transação",
    "Payoff process": "Processo de quitação",
    "Credit line increase/decrease": "Aumento/redução da linha de crédito",
    "Unsolicited issuance of credit card": "Emissão não solicitada de cartão de crédito",
    "Shopping for a loan or lease": "Busca por empréstimo ou leasing",
    "Money was not available when promised": "Dinheiro não estava disponível como prometido",
    "Unauthorized transactions/trans. issues": "Transações não autorizadas / Problemas de transação",
    "Can't contact lender": "Não consigo contatar o credor",
    "Getting a loan": "Obtendo um empréstimo",
    "Managing, opening, or closing account": "Gerenciamento, abertura ou fechamento de conta",
    "Balance transfer": "Transferência de saldo",
    "Received a loan I didn't apply for": "Recebi um empréstimo que não solicitei",
    "Credit reporting": "Relatório de crédito",
    "Can't stop charges to bank account": "Não consigo parar cobranças na conta bancária",
    "Account terms and changes": "Termos e alterações da conta",
    "Privacy": "Privacidade",
    "Collection practices": "Práticas de cobrança",
    "Bankruptcy": "Falência",
    "Forbearance / Workout plans": "Tolerância / Planos de renegociação",
    "Wrong amount charged or received": "Valor cobrado ou recebido incorretamente",
    "Application processing delay": "Atraso no processamento da aplicação",
    "Managing the line of credit": "Gerenciamento da linha de crédito",
    "Shopping for a line of credit": "Busca por linha de crédito",
    "Payment to acct not credited": "Pagamento não creditado na conta",
    "Applied for loan/did not receive money": "Solicitei empréstimo / não recebi o valor",
    "Arbitration": "Arbitragem",
    "Collection debt dispute": "Disputa de dívida em cobrança",
    "Cash advance": "Adiantamento em dinheiro",
    "Incorrect/missing disclosures or info": "Divulgações ou informações incorretas/incompletas",
    "Sale of account": "Venda da conta",
    "Customer service/Customer relations": "Atendimento ao cliente / Relações com o cliente",
    "Fees": "Taxas",
    "Balance transfer fee": "Taxa de transferência de saldo",
    "Adding money": "Adicionando dinheiro",
    "Charged bank acct wrong day or amt": "Cobrança em conta em dia ou valor errado",
    "Convenience checks": "Cheques de conveniência",
    "Cash advance fee": "Taxa de adiantamento em dinheiro",
    "Overlimit fee": "Taxa por ultrapassar o limite",
    "Lender repossessed or sold the vehicle": "Credor retomou ou vendeu o veículo",
    "Incorrect exchange rate": "Taxa de câmbio incorreta",
    "Disclosures": "Divulgações",
    "Advertising, marketing or disclosures": "Publicidade, marketing ou divulgações",
    "Lost or stolen money order": "Ordem de pagamento perdida ou roubada"
}

# %%
df["Issue"] = df["Issue"].map(issue_translation_dict)

# %%
df.head()
# Out:
#         ID                           Company                 Product  \
# 0  1615767                      PHH Mortgage  Empréstimo Imobiliário
# 1   654223                             Ocwen  Empréstimo Imobiliário
# 2  1143398    Southwest Credit Systems, L.P.     Cobrança de Dívidas
# 3  1303679  Continental Finance Company, LLC       Cartão de Crédito
# 4  1627370                          Experian    Relatório de Crédito
#
#                                                Issue State Submitted via  \
# 0  Serviço do empréstimo, pagamentos, conta garan...    FL           Web
# 1  Serviço do empréstimo, pagamentos, conta garan...    NC           Web
# 2  Modificação de empréstimo, cobrança, execução ...    MO           Web
# 3                                             Fatura    WA           Web
# 4        Incapaz de obter relatório de crédito/score    VA           Web
#
#   Date received Date resolved Timely response? Consumer disputed?  \
# ...

# %%
df["Consumer disputed"] = df["Consumer disputed?"].map({"Yes": 1, "No": 0})

# %%
df.to_csv("dataset_finance.csv", index=False)
